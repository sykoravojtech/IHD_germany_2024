# %%
import pandas as pd
from csv_data_manipulation import melt_all_year_cols_into_one

# %%
INPUT_FILE = "../data/raw/wdi_tobaccoalcohol_population.csv"
OUTPUT_FILE = "../data/final/wdi_AlcoholConsumption.csv"

# %%
melted_df = melt_all_year_cols_into_one(
    input_file = INPUT_FILE, 
    output_file = OUTPUT_FILE,
    replace_dots = True,
    remove_nan = True,
    one_series = ("Series Name", "Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)"),
    remove_cols = ["Series Code"])
melted_df
# Out:
# Loading ../data/raw/wdi_tobaccoalcohol_population.csv
# Removing cols ['Series Code']
# Leaving only 'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)' in 'Series Name'
# DataFrame saved to ../data/final/wdi_AlcoholConsumption.csv
#        Country Name Country Code  \
# 2170    Afghanistan          AFG
# 2171        Albania          ALB
# 2172        Algeria          DZA
# 2174        Andorra          AND
# 2175         Angola          AGO
# ...             ...          ...
# 6503  Venezuela, RB          VEN
# 6504       Viet Nam          VNM
# 6507    Yemen, Rep.          YEM
# 6508         Zambia          ZMB
# 6509       Zimbabwe          ZWE
#
#                                             Series Name  Year     Value
# 2170  Total alcohol consumption per capita (liters o...  2000   0.00277
# 2171  Total alcohol consumption per capita (liters o...  2000   4.43100
# 2172  Total alcohol consumption per capita (liters o...  2000   0.30323
# 2174  Total alcohol consumption per capita (liters o...  2000  12.54881
# 2175  Total alcohol consumption per capita (liters o...  2000   5.18632
# ...                                                 ...   ...       ...
# 6503  Total alcohol consumption per capita (liters o...  2019   3.01625
# 6504  Total alcohol consumption per capita (liters o...  2019   9.33984
# 6507  Total alcohol consumption per capita (liters o...  2019   0.02778
# 6508  Total alcohol consumption per capita (liters o...  2019   3.85176
# 6509  Total alcohol consumption per capita (liters o...  2019   3.62809
#
# [931 rows x 5 columns]
