# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

import sys
from pathlib import Path
# Add the parent directory to the sys.path (without this we cannot import constants or scripts)
sys.path.insert(0, str(Path.cwd().parent))
from constants.countries import highincome_countries
from src import generate_high_income_global_avg_index
from src.plotting import plot_value_per_year_GER_HIC_GLO

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

import sys
from pathlib import Path
# Add the parent directory to the sys.path (without this we cannot import constants or scripts)
sys.path.insert(0, str(Path.cwd().parent))
from constants.countries import highincome_countries
from src import generate_high_income_global_avg_index
from src.plotting import plot_value_per_year_GER_HIC_GLO

# %%
DATA_PATH = "../data/final/"
OUTPUT_PATH = "output/" # if you want to save the plots
alcohol_data_path = DATA_PATH + "daily_per_capita_fat_supply_final.csv"
VALUE_COLUMN_NAME = "Value"
YEAR_COLUMN_NAME = "Year"

# %%
df = pd.read_csv(alcohol_data_path)
df
# Out:
#       Country Name Country Code                                 Series Name  \
# 0      Afghanistan          AFG  Fat consumption per day per capita (grams)
# 1      Afghanistan          AFG  Fat consumption per day per capita (grams)
# 2      Afghanistan          AFG  Fat consumption per day per capita (grams)
# 3      Afghanistan          AFG  Fat consumption per day per capita (grams)
# 4      Afghanistan          AFG  Fat consumption per day per capita (grams)
# ...            ...          ...                                         ...
# 12355     Zimbabwe          ZWE  Fat consumption per day per capita (grams)
# 12356     Zimbabwe          ZWE  Fat consumption per day per capita (grams)
# 12357     Zimbabwe          ZWE  Fat consumption per day per capita (grams)
# 12358     Zimbabwe          ZWE  Fat consumption per day per capita (grams)
# 12359     Zimbabwe          ZWE  Fat consumption per day per capita (grams)
#
#        Year      Value
# 0      1961  38.209236
# 1      1962  38.335213
# 2      1963  39.338820
# 3      1964  39.747234
# 4      1965  40.560085
# ...     ...        ...
# 12355  2016  66.536940
# 12356  2017  62.848648
# 12357  2018  64.250500
# 12358  2019  56.008080
# 12359  2020  60.942127
#
# [12360 rows x 5 columns]

# %%
# Appending the average data to the original DataFrame
df = generate_high_income_global_avg_index(df)

# Display the last few rows to verify the appended averages
df
# Out:
#    Country Name Country Code                                 Series Name  \
# 0   Afghanistan          AFG  Fat consumption per day per capita (grams)
# 1   Afghanistan          AFG  Fat consumption per day per capita (grams)
# 2   Afghanistan          AFG  Fat consumption per day per capita (grams)
# 3   Afghanistan          AFG  Fat consumption per day per capita (grams)
# 4   Afghanistan          AFG  Fat consumption per day per capita (grams)
# ..          ...          ...                                         ...
# 55       Global          GLB  Fat consumption per day per capita (grams)
# 56       Global          GLB  Fat consumption per day per capita (grams)
# 57       Global          GLB  Fat consumption per day per capita (grams)
# 58       Global          GLB  Fat consumption per day per capita (grams)
# 59       Global          GLB  Fat consumption per day per capita (grams)
#
#     Year      Value
# 0   1961  38.209236
# 1   1962  38.335213
# 2   1963  39.338820
# 3   1964  39.747234
# 4   1965  40.560085
# ..   ...        ...
# 55  2016  88.634241
# 56  2017  89.560881
# 57  2018  90.743918
# 58  2019  93.035794
# 59  2020  93.594264
#
# [12480 rows x 5 columns]

# %%
plot_value_per_year_GER_HIC_GLO(
    df, 
    xticks = 5, 
    output_fig_path = OUTPUT_PATH + "FatConsumptionPerCapita.pdf",
    xlabel = 'Year',
    ylabel = "Grams of fat",
    title = "Daily fat consumption per capita")
